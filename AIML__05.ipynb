# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanabayya30/Ai-ml_2303A52019/blob/main/AIML__05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import packages and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/titanic_train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Check basic info on the data set
#
# 'info()' method to check the data types and number

# %%
df = pd.read_csv("/content/drive/MyDrive/titanic_train.csv")
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 'describe()' method to get the statistical summary of the various features of the data set

# %%
df.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 10%      90.000000    0.000000    1.000000   14.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# 90%     802.000000    1.000000    3.000000   50.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 10%      0.000000    7.550000
# 25%      0.000000    7.910400
# ...

# %% [markdown]
# 'columns' method to get the names of the columns (features)

# %%
df = pd.read_csv("/content/drive/MyDrive/titanic_train.csv")
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Basic plotting and visualization on the data set
#
# Pairplots using seaborn

# %%
# Create a colorful pairplot
sns.pairplot(df, hue='Survived', palette='bright', markers=['o', 's'])

# Show the plot
plt.show()

# %% [markdown]
# Distribution of price (the predicted quantity)

# %%
# Plot histogram of 'Fare'
df['Fare'].plot.hist(bins=25, figsize=(8,4))

# Set title and labels
plt.title('Distribution of Passenger Fare')
plt.xlabel('Fare')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Plot density plot of 'Fare'
sns.kdeplot(df['Fare'])

# Set title and labels
plt.title('Density Plot of Passenger Fare')
plt.xlabel('Fare')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
df['Fare'].plot.density(figsize=(8,4))
plt.title('Density Plot of Passenger Fare')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Correlation matrix and heatmap

# %%
df = pd.read_csv("/content/drive/MyDrive/titanic_train.csv")

# Separate numeric and categorical columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Calculate correlation matrix for numeric columns
corr_matrix = df[numeric_cols].corr()

# Display correlation matrix
print(corr_matrix)

# Visualize correlation matrix using heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# Select numerical columns
numerical_df = df.select_dtypes(include=['int64', 'float64'])

# Create heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(numerical_df.corr(),
            annot=True,
            linewidths=2,
            cmap='coolwarm',
            linecolor='white')

# Set labels and title
plt.title('Correlation Matrix')
plt.xlabel('Features')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# Feature and variable sets
# Make a list of data frame column names

# %%
## Y = MX +C where Y is dependent, X is independent features
## M is slope, C is intercept
l_column = list(df.columns) # Making a list out of column names
len_feature = len(l_column) # Length of column vector list
l_column, len_feature
# Out:
# (['PassengerId',
#   'Survived',
#   'Pclass',
#   'Name',
#   'Sex',
#   'Age',
#   'SibSp',
#   'Parch',
#   'Ticket',
#   'Fare',
#   'Cabin',
#   'Embarked'],
#  12)

# %% [markdown]
# Put all the numerical features in X and Median House Value in y,
# ignore lat, long which is string for linear regression

# %%
X = df[l_column[2:len_feature-1]]
y = df[l_column[len_feature-1]]

# %%
print("Feature set size:",X.shape)
print("Variable set size:",y.shape)
# Out:
# Feature set size: (891, 9)
# Variable set size: (891,)

# %%
X.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin
# 0      1      0         A/5 21171   7.2500   NaN
# 1      1      0          PC 17599  71.2833   C85
# 2      0      0  STON/O2. 3101282   7.9250   NaN
# 3      1      0            113803  53.1000  C123
# 4      0      0            373450   8.0500   NaN

# %%
y.head()
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %% [markdown]
# Part -02: Test-train split
#
# Import train_test_split function from scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Create X and y train and test splits into 80-20 ratio in one command using
# a split ratio and a random seed

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
print(y_train.shape, y_test.shape, X_train.shape, X_test.shape)
# Out:
# (712,) (179,) (712, 9) (179, 9)

# %% [markdown]
# Check the size and shape of train/test splits (it should be in the ratio as per test_size parameter above)

# %%
# Calculate sizes
train_size = len(X_train)
test_size = len(X_test)

# Calculate ratios
train_ratio = train_size / (train_size + test_size)
test_ratio = test_size / (train_size + test_size)

print("Train size:", train_size)
print("Test size:", test_size)
print("Train ratio:", train_ratio)
print("Test ratio:", test_ratio)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# Train size: 712
# Test size: 179
# Train ratio: 0.7991021324354658
# Test ratio: 0.20089786756453423
# X_train shape: (712, 9)
# X_test shape: (179, 9)
# y_train shape: (712,)
# y_test shape: (179,)

# %% [markdown]
# Model fit and training
#
# Import linear regression model estimator from scikit-learn and instantiate

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn import metrics

# %%
lm = LinearRegression()

# %% [markdown]
# Fit the model on to the instantiated object itself

# %%
lm.fit(X_train,y_train)
